# %% [markdown]
# # Application The GRU ( RNN ) To predict next year Temperature value based on 30 years of time series Nasa dataset contain daily/ monthly data

# %%
import pandas as pd
data = pd.read_csv('POWER_Point_Daily.csv')

data.columns
# Out:
# Index(['ALLSKY_KT', 'ALLSKY_SFC_SW_DWN', 'CLRSKY_SFC_SW_DWN', 'WS2M', 'T2M',
#        'RH2M', 'PS'],
#       dtype='object')

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
from scipy.stats import zscore

# Create a sample df
df = pd.DataFrame(data)

# Calculate the zscores and drop zscores into new column
df['ALLSKY_KT'] = zscore(df['ALLSKY_KT'])
df['ALLSKY_SFC_SW_DWN'] = zscore(df['ALLSKY_SFC_SW_DWN'])
df['CLRSKY_SFC_SW_DWN'] = zscore(df['CLRSKY_SFC_SW_DWN'])
df['WS2M'] = zscore(df['WS2M'])
df['T2M'] = zscore(df['T2M'])
df['RH2M'] = zscore(df['RH2M'])
df['PS'] = zscore(df['PS'])
data = df
display(data)
# Out:
#        ALLSKY_KT  ALLSKY_SFC_SW_DWN  CLRSKY_SFC_SW_DWN      WS2M       T2M  \
# 0      -0.557885          -1.330527          -1.603895  0.008261 -0.942606
# 1      -0.304483          -1.247410          -1.455397 -0.787709 -1.083493
# 2      -0.135549          -1.195462          -1.346879 -1.098516 -1.116899
# 3      -2.500631          -1.886370          -1.352590 -0.802870 -1.228737
# 4      -2.416164          -1.865591          -1.398282  0.447939 -1.021038
# ...          ...                ...                ...       ...       ...
# 11408   1.046992           0.757781           0.566463 -0.150933 -0.477824
# 11409   0.793591           0.669470           0.595021 -1.098516 -0.161191
# 11410   1.046992           0.809729           0.589309 -0.181256 -0.541731
# 11411   1.046992           0.804534           0.732096 -0.317708 -0.594019
# 11412   0.878058           0.747392           0.754942 -0.992387 -0.653569
#
#            RH2M        PS
# 0      0.842289 -0.320943
# 1      0.437016  0.463772
# 2      0.335050  0.285427
# 3      0.739459 -0.463619
# 4      1.895652 -0.392281
# ...         ...       ...
# 11408 -1.949684  1.801354
# 11409 -2.381744  1.961864
# 11410  0.939934  2.265049
# 11411  0.983140  1.890526
# 11412  0.523428  1.248487
#
# [11413 rows x 7 columns]

# %%
data.shape
# Out:
# (11413, 7)

# %% [markdown]
# ## Visualisation de données

# %%
# import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20,7))
# Évolution de la pression
ax1 = fig.add_subplot(221)
plt.plot(data['PS'])
ax1.title.set_text('Pression')
# Évolution de la température
ax2 = fig.add_subplot(222)
plt.plot(data['T2M'])
ax2.title.set_text('Température')
# Évolution de la saturation
ax3 = fig.add_subplot(223)
plt.plot(data['RH2M'])
ax3.title.set_text('Saturation')
# Évolution du déficit de pression de vapeur
ax4 = fig.add_subplot(224)
plt.plot(data['WS2M'])
ax4.title.set_text('Déficit de pression de vapeur')
plt.show()

# %%
split_fraction = 0.80
split_idx =int(split_fraction * len(data))
# Train: on conserve les 80% premières lignes
train_data = data.loc[0:split_idx-1].values
# Test: on conserve les 20% dernières lignes
val_data = data.loc[split_idx:].values
print(f"Jeu d'apprentissage : {train_data.shape}, jeu d'évaluation : {val_data.shape}")
# Out:
# Jeu d'apprentissage : (9130, 7), jeu d'évaluation : (2283, 7)

# %% [markdown]
# ## Entraîner notre réseau de neurones par descente de gradient

# %%
# Importation 
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import matplotlib as plt

# %%
# Création du jeu d'entraînement

sampling_rate = 6 # Fréquence d'échantillonnage
sequence_length = 360  # Longueur de la séquence
batch_size = 120 # Taille de batch

# Création du jeu d'entraînement

X_train = tf.keras.utils.timeseries_dataset_from_array(
    data=train_data[:, (0,1,2,3,5,6)],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

y_train = tf.keras.utils.timeseries_dataset_from_array(
    data=train_data[:, 4],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)


dataset_train = tf.data.Dataset.zip((X_train, y_train))

# %%
# Création du jeu d'évaluation

X_val = tf.keras.utils.timeseries_dataset_from_array(
    data=val_data[:, (0,2,1,3,5,6)],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

y_val = tf.keras.utils.timeseries_dataset_from_array(
    data=val_data[:, 4],
    targets=None,
    sequence_length=sequence_length,
    sampling_rate=sampling_rate,
    batch_size=batch_size,
)

dataset_val = tf.data.Dataset.zip((X_val, y_val))

# %% [markdown]
# ## Training GRU RNN

# %%
from tensorflow import keras

# %%
dimension = train_data.shape[1]-1
inputs = keras.layers.Input(shape=(sequence_length, dimension))
gru_out = keras.layers.GRU(dimension, return_sequences=True)(inputs)
dense_out = keras.layers.Dense(dimension, activation='relu')(gru_out)
outputs = keras.layers.Dense(1)(dense_out)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
learning_rate = 0.001
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 360, 6)]          0
#
#  gru_6 (GRU)                 (None, 360, 6)            252
#
#  dense_12 (Dense)            (None, 360, 6)            42
#
#  dense_13 (Dense)            (None, 360, 1)            7
#
# =================================================================
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 5

model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
)
# Out:
# Epoch 1/5
# 59/59 [==============================] - 11s 153ms/step - loss: 0.7276 - val_loss: 0.5559
# Epoch 2/5
# 59/59 [==============================] - 8s 144ms/step - loss: 0.4474 - val_loss: 0.3330
# Epoch 3/5
# 59/59 [==============================] - 8s 138ms/step - loss: 0.3215 - val_loss: 0.2473
# Epoch 4/5
# 59/59 [==============================] - 9s 149ms/step - loss: 0.2332 - val_loss: 0.1840
# Epoch 5/5
# 59/59 [==============================] - 9s 148ms/step - loss: 0.1702 - val_loss: 0.1393

# %%
import matplotlib.pyplot as plt 
from matplotlib.pyplot import scatter
def show_plot(predicted_data, true_data):
    plt.title('Prédiction synchrone')
    plt.plot(predicted_data, "rx", label="Température prédite")
    plt.plot(true_data, ".-", label="Vraie température")
    plt.legend()
    plt.xlabel("Pas de temps/jours")
    plt.show()
    return

# %%
for x, y in dataset_val.take(3):
     show_plot(y[0].numpy(), model.predict(x)[0])
# Out:
# 4/4 [==============================] - 1s 31ms/step
# 1/1 [==============================] - 0s 31ms/step

# %%
mean_absolute_error = tf.keras.losses.MeanAbsoluteError()
error = 0

for x, y in dataset_val:
    y_pred = model(x)
    error += mean_absolute_error(y, y_pred).numpy()

print(f"Erreur absolue moyenne : {error/len(dataset_val):.5f}")
# Out:
# Erreur absolue moyenne : 0.28668

# %% [markdown]
# ## Prédiction de la température future

# %%
past_length = 720
future_step = 6

label_start = past_length + future_step  # Début de la séquence des labels
label_end = label_start + split_idx  # Fin de la séquence des labels

x_train = train_data
y_train = data[label_start:label_end][['T2M']]

x_end = len(val_data) - past_length - future_step # Fin de la séquence des données d'entrées en validation

label_start = split_idx + past_length + future_step # Début de la séquence des labels en validation
x_val = val_data[:x_end]
y_val = data[label_start:][['T2M']]

# %%
batch_size = 365
step_size = 6 # Facteur d'échantillonnage
sequence_length = int(past_length / step_size)

dataset_train = tf.keras.utils.timeseries_dataset_from_array(
    x_train,
    y_train,
    sequence_length=sequence_length,
    sampling_rate=step_size,
    batch_size=batch_size,
)

dataset_val = keras.preprocessing.timeseries_dataset_from_array(
    x_val,
    y_val,
    sequence_length=sequence_length,
    sampling_rate=step_size,
    batch_size=batch_size,
)

# %% [markdown]
# Comme précédemment, nous allons entraîner un réseau récurrent constitué d’une couche récurrente utilisant la cellule GRU et de deux couches linéaires séparées par une activation ReLU.

# %%
learning_rate = 0.001

input_dim = train_data.shape[1]
hidden_dim = 32
inputs = keras.layers.Input(shape=(sequence_length, input_dim))
gru_out = keras.layers.GRU(hidden_dim)(inputs)
dense_out = keras.layers.Dense(hidden_dim, activation='relu')(gru_out)
outputs = keras.layers.Dense(1)(dense_out)

model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
model.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 120, 7)]          0
#
#  gru_8 (GRU)                 (None, 32)                3936
#
#  dense_16 (Dense)            (None, 32)                1056
#
#  dense_17 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 5,025
# Trainable params: 5,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 5

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_val,
)
# Out:
# Epoch 1/5
# 24/24 [==============================] - 6s 153ms/step - loss: 0.3604 - val_loss: 0.1258
# Epoch 2/5
# 24/24 [==============================] - 3s 138ms/step - loss: 0.1254 - val_loss: 0.1024
# Epoch 3/5
# 24/24 [==============================] - 3s 134ms/step - loss: 0.1025 - val_loss: 0.1013
# Epoch 4/5
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0979 - val_loss: 0.0986
# Epoch 5/5
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0960 - val_loss: 0.0961

# %% [markdown]
# Pour terminer, on peux désormais visualisons les résultats en prédiction de ma modèle sur les trois premières séquences du jeu de validation :

# %%
def show_plot(sequence, prediction, ground_truth, delta=future_step/step_size, title=None):
    plt.title(title)
    plt.plot(sequence.flatten(), ".-", label="Température passée")
    plt.plot(len(sequence) + delta, prediction, "go", label="Prédiction")
    plt.plot(len(sequence) + delta, ground_truth, "rx", label="Vraie température")
    plt.legend()
    plt.xlim(-1, len(sequence) + delta + 3)
    plt.xlabel("Pas de temps")
    plt.show()

# %%
for x, y in dataset_val.take(5):
    show_plot(x[0][:, 1].numpy(), model.predict(x)[0], y[0].numpy(), title="Prédiction de la température")
# Out:
# 12/12 [==============================] - 1s 11ms/step
# 12/12 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 15ms/step
